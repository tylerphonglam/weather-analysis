# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}?q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | troitsko-pechorsk
# Processing Record 2 of Set 1 | gurupi
# Processing Record 3 of Set 1 | thunder bay
# Processing Record 4 of Set 1 | edinburgh of the seven seas
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | iskateley
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 9 of Set 1 | sinabang
# Processing Record 10 of Set 1 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 1 | puerto natales
# Processing Record 14 of Set 1 | chui
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | bilibino
# Processing Record 17 of Set 1 | stanley
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | gadzhiyevo
# Processing Record 21 of Set 1 | margaret river
# Processing Record 22 of Set 1 | talnakh
# Processing Record 23 of Set 1 | west island
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | buga
# Processing Record 26 of Set 1 | port mathurin
# Processing Record 27 of Set 1 | fortuna
# Processing Record 28 of Set 1 | hamilton
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | mejit
# Processing Record 31 of Set 1 | ko samui
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | klyuchi
# Processing Record 34 of Set 1 | newman
# Processing Record 35 of Set 1 | ilulissat
# Processing Record 36 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 37 of Set 1 | adamstown
# Processing Record 38 of Set 1 | ha'il
# Processing Record 39 of Set 1 | mwinilunga
# Processing Record 40 of Set 1 | kota bharu
# Processing Record 41 of Set 1 | usogorsk
# Processing Record 42 of Set 1 | okha
# Processing Record 43 of Set 1 | belmonte
# Processing Record 44 of Set 1 | lata
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | booue
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | sarangani
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | bethel
# Processing Record 0 of Set 2 | tiksi
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | shingu
# Processing Record 3 of Set 2 | yuzhno-kurilsk
# Processing Record 4 of Set 2 | ola
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | zharkent
# Processing Record 7 of Set 2 | flin flon
# Processing Record 8 of Set 2 | saipan
# Processing Record 9 of Set 2 | nazarabad
# Processing Record 10 of Set 2 | tomohon
# Processing Record 11 of Set 2 | nadym
# Processing Record 12 of Set 2 | khash
# Processing Record 13 of Set 2 | waitangi
# Processing Record 14 of Set 2 | whitehorse
# Processing Record 15 of Set 2 | brixham
# Processing Record 16 of Set 2 | amursk
# Processing Record 17 of Set 2 | tabou
# Processing Record 18 of Set 2 | micheweni
# Processing Record 19 of Set 2 | isafjordur
# Processing Record 20 of Set 2 | oliver
# Processing Record 21 of Set 2 | antofagasta
# Processing Record 22 of Set 2 | elverum
# Processing Record 23 of Set 2 | blackmans bay
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | hawaiian paradise park
# Processing Record 26 of Set 2 | san antonio de pale
# Processing Record 27 of Set 2 | fisterra
# Processing Record 28 of Set 2 | luba
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | gudur
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | coquimbo
# Processing Record 34 of Set 2 | ramhormoz
# Processing Record 35 of Set 2 | wailua homesteads
# Processing Record 36 of Set 2 | keflavik
# Processing Record 37 of Set 2 | banda aceh
# Processing Record 38 of Set 2 | pasuquin
# Processing Record 39 of Set 2 | lazaro cardenas
# Processing Record 40 of Set 2 | leninsk
# Processing Record 41 of Set 2 | colonia
# Processing Record 42 of Set 2 | tura
# Processing Record 43 of Set 2 | bodaybo
# Processing Record 44 of Set 2 | saldanha
# Processing Record 45 of Set 2 | yevpatoriya
# Processing Record 46 of Set 2 | rioblanco
# Processing Record 47 of Set 2 | kavaratti
# Processing Record 48 of Set 2 | tommot
# Processing Record 49 of Set 2 | timbiqui
# Processing Record 0 of Set 3 | avarua
# Processing Record 1 of Set 3 | mount isa
# Processing Record 2 of Set 3 | aykol
# City not found. Skipping...
# Processing Record 3 of Set 3 | fukuecho
# Processing Record 4 of Set 3 | merzig
# Processing Record 5 of Set 3 | papatowai
# Processing Record 6 of Set 3 | ardakan
# Processing Record 7 of Set 3 | pathein
# Processing Record 8 of Set 3 | singaparna
# Processing Record 9 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 10 of Set 3 | basco
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | mitchell
# Processing Record 13 of Set 3 | afaahiti
# Processing Record 14 of Set 3 | chegdomyn
# Processing Record 15 of Set 3 | ixtapa
# Processing Record 16 of Set 3 | turiacu
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | orsa
# Processing Record 19 of Set 3 | ta`u
# Processing Record 20 of Set 3 | alofi
# Processing Record 21 of Set 3 | amga
# Processing Record 22 of Set 3 | vorgashor
# Processing Record 23 of Set 3 | constantia
# Processing Record 24 of Set 3 | college
# Processing Record 25 of Set 3 | puerto baquerizo moreno
# Processing Record 26 of Set 3 | phnom penh
# Processing Record 27 of Set 3 | minas de marcona
# Processing Record 28 of Set 3 | fort saskatchewan
# Processing Record 29 of Set 3 | sattahip
# Processing Record 30 of Set 3 | vikulovo
# Processing Record 31 of Set 3 | lautoka
# Processing Record 32 of Set 3 | harstad
# Processing Record 33 of Set 3 | lihue
# Processing Record 34 of Set 3 | altai
# Processing Record 35 of Set 3 | panacan
# Processing Record 36 of Set 3 | utrik
# Processing Record 37 of Set 3 | namibe
# Processing Record 38 of Set 3 | sigli
# Processing Record 39 of Set 3 | patur
# Processing Record 40 of Set 3 | strezhevoy
# Processing Record 41 of Set 3 | devinuwara
# City not found. Skipping...
# Processing Record 42 of Set 3 | albany
# Processing Record 43 of Set 3 | monte argentario
# Processing Record 44 of Set 3 | kitimat
# Processing Record 45 of Set 3 | rongelap
# Processing Record 46 of Set 3 | la ronge
# Processing Record 47 of Set 3 | jamestown
# Processing Record 48 of Set 3 | paracuru
# Processing Record 49 of Set 3 | lompoc
# Processing Record 0 of Set 4 | amahai
# Processing Record 1 of Set 4 | ceeldheer
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | udachny
# Processing Record 4 of Set 4 | port saint john's
# Processing Record 5 of Set 4 | i-n-salah
# Processing Record 6 of Set 4 | kapa'a
# Processing Record 7 of Set 4 | gamba
# Processing Record 8 of Set 4 | rainsville
# Processing Record 9 of Set 4 | dabakala
# Processing Record 10 of Set 4 | chonchi
# Processing Record 11 of Set 4 | ciudad lazaro cardenas
# Processing Record 12 of Set 4 | shizunai-furukawacho
# Processing Record 13 of Set 4 | houghton
# Processing Record 14 of Set 4 | hammerfest
# Processing Record 15 of Set 4 | funafuti
# Processing Record 16 of Set 4 | punta arenas
# Processing Record 17 of Set 4 | khandyga
# Processing Record 18 of Set 4 | guerrero negro
# Processing Record 19 of Set 4 | castillos
# Processing Record 20 of Set 4 | st. john's
# Processing Record 21 of Set 4 | jiagedaqi
# Processing Record 22 of Set 4 | koryazhma
# Processing Record 23 of Set 4 | fuglafjordur
# Processing Record 24 of Set 4 | yangor
# City not found. Skipping...
# Processing Record 25 of Set 4 | ulanhot
# Processing Record 26 of Set 4 | la'ie
# Processing Record 27 of Set 4 | glendive
# Processing Record 28 of Set 4 | fort bragg
# Processing Record 29 of Set 4 | plettenberg bay
# Processing Record 30 of Set 4 | trairi
# Processing Record 31 of Set 4 | zarate
# Processing Record 32 of Set 4 | rukban
# City not found. Skipping...
# Processing Record 33 of Set 4 | madang
# Processing Record 34 of Set 4 | zeya
# Processing Record 35 of Set 4 | kobuleti
# Processing Record 36 of Set 4 | takamaka
# City not found. Skipping...
# Processing Record 37 of Set 4 | olonkinbyen
# Processing Record 38 of Set 4 | tolanaro
# Processing Record 39 of Set 4 | la sarre
# Processing Record 40 of Set 4 | rundu
# Processing Record 41 of Set 4 | marka
# Processing Record 42 of Set 4 | happy valley-goose bay
# Processing Record 43 of Set 4 | aoulef
# Processing Record 44 of Set 4 | laguna
# Processing Record 45 of Set 4 | kalakkadu
# Processing Record 46 of Set 4 | kuqa
# Processing Record 47 of Set 4 | lamar
# Processing Record 48 of Set 4 | mossel bay
# Processing Record 49 of Set 4 | klichaw
# Processing Record 0 of Set 5 | fale old settlement
# Processing Record 1 of Set 5 | camp verde
# Processing Record 2 of Set 5 | invercargill
# Processing Record 3 of Set 5 | deqen
# Processing Record 4 of Set 5 | san jose village
# City not found. Skipping...
# Processing Record 5 of Set 5 | vilyuchinsk
# Processing Record 6 of Set 5 | badger
# Processing Record 7 of Set 5 | cassilandia
# Processing Record 8 of Set 5 | chernyshevskiy
# Processing Record 9 of Set 5 | thulamahashi
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | jonesboro
# Processing Record 12 of Set 5 | dryden
# Processing Record 13 of Set 5 | mirny
# Processing Record 14 of Set 5 | cuito
# Processing Record 15 of Set 5 | el bauga
# Processing Record 16 of Set 5 | notodden
# Processing Record 17 of Set 5 | queenstown
# Processing Record 18 of Set 5 | touros
# Processing Record 19 of Set 5 | sarykemer
# Processing Record 20 of Set 5 | acapulco de juarez
# Processing Record 21 of Set 5 | kargasok
# Processing Record 22 of Set 5 | beira
# Processing Record 23 of Set 5 | trenggalek
# Processing Record 24 of Set 5 | karratha
# Processing Record 25 of Set 5 | papao
# Processing Record 26 of Set 5 | porto novo
# Processing Record 27 of Set 5 | san sebastian de la gomera
# Processing Record 28 of Set 5 | kidal
# Processing Record 29 of Set 5 | santa marta
# Processing Record 30 of Set 5 | santo pipo
# Processing Record 31 of Set 5 | tralee
# Processing Record 32 of Set 5 | haiku-pauwela
# Processing Record 33 of Set 5 | qaqortoq
# Processing Record 34 of Set 5 | querecotillo
# Processing Record 35 of Set 5 | burao
# Processing Record 36 of Set 5 | lerwick
# Processing Record 37 of Set 5 | fairfax
# Processing Record 38 of Set 5 | puerto ayora
# Processing Record 39 of Set 5 | enewetak
# Processing Record 40 of Set 5 | novo aripuana
# Processing Record 41 of Set 5 | fortaleza
# Processing Record 42 of Set 5 | suva
# Processing Record 43 of Set 5 | manta
# Processing Record 44 of Set 5 | banyo
# Processing Record 45 of Set 5 | tamanrasset
# Processing Record 46 of Set 5 | anadyr
# Processing Record 47 of Set 5 | fomboni
# Processing Record 48 of Set 5 | tatarbunary
# Processing Record 49 of Set 5 | malvan
# Processing Record 0 of Set 6 | tromso
# Processing Record 1 of Set 6 | havre
# Processing Record 2 of Set 6 | igarka
# Processing Record 3 of Set 6 | new norfolk
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | plouzane
# Processing Record 6 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 7 of Set 6 | maple ridge
# Processing Record 8 of Set 6 | yeniseysk
# Processing Record 9 of Set 6 | inhambane
# Processing Record 10 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 11 of Set 6 | loango
# Processing Record 12 of Set 6 | piti village
# Processing Record 13 of Set 6 | agua prieta
# Processing Record 14 of Set 6 | zhanaozen
# Processing Record 15 of Set 6 | wuhai
# Processing Record 16 of Set 6 | vernon
# Processing Record 17 of Set 6 | sangsong-ni
# Processing Record 18 of Set 6 | lethbridge
# Processing Record 19 of Set 6 | taoudenni
# Processing Record 20 of Set 6 | harrisonville
# Processing Record 21 of Set 6 | zhaotong
# Processing Record 22 of Set 6 | kapuskasing
# Processing Record 23 of Set 6 | cockburn town
# Processing Record 24 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 25 of Set 6 | show low
# Processing Record 26 of Set 6 | al jawf
# Processing Record 27 of Set 6 | lorengau
# Processing Record 28 of Set 6 | nova vicosa
# Processing Record 29 of Set 6 | arno
# Processing Record 30 of Set 6 | lekki
# City not found. Skipping...
# Processing Record 31 of Set 6 | dunedin
# Processing Record 32 of Set 6 | paradip garh
# Processing Record 33 of Set 6 | zavolzhsk
# Processing Record 34 of Set 6 | kenora
# Processing Record 35 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 36 of Set 6 | egilsstadir
# Processing Record 37 of Set 6 | lodja
# Processing Record 38 of Set 6 | aasiaat
# Processing Record 39 of Set 6 | black point
# Processing Record 40 of Set 6 | kruisfontein
# Processing Record 41 of Set 6 | saint-felicien
# Processing Record 42 of Set 6 | ingeniero jacobacci
# Processing Record 43 of Set 6 | touba
# Processing Record 44 of Set 6 | nacozari viejo
# Processing Record 45 of Set 6 | huarmey
# Processing Record 46 of Set 6 | san antonio
# Processing Record 47 of Set 6 | yerofey pavlovich
# Processing Record 48 of Set 6 | langepas
# Processing Record 49 of Set 6 | damghan
# Processing Record 0 of Set 7 | chulym
# Processing Record 1 of Set 7 | aripuana
# Processing Record 2 of Set 7 | bayanhongor
# Processing Record 3 of Set 7 | kupang
# Processing Record 4 of Set 7 | mitu
# Processing Record 5 of Set 7 | renk
# City not found. Skipping...
# Processing Record 6 of Set 7 | saudarkrokur
# Processing Record 7 of Set 7 | gustavsberg
# Processing Record 8 of Set 7 | hasaki
# Processing Record 9 of Set 7 | beytussebap
# Processing Record 10 of Set 7 | hermanus
# Processing Record 11 of Set 7 | nouadhibou
# Processing Record 12 of Set 7 | mugia
# Processing Record 13 of Set 7 | kapit
# Processing Record 14 of Set 7 | saint-pierre
# Processing Record 15 of Set 7 | guarapari
# Processing Record 16 of Set 7 | ouled mimoun
# Processing Record 17 of Set 7 | koregaon
# Processing Record 18 of Set 7 | dudinka
# Processing Record 19 of Set 7 | vilyuysk
# Processing Record 20 of Set 7 | praia da vitoria
# Processing Record 21 of Set 7 | boguchany
# Processing Record 22 of Set 7 | holualoa
# Processing Record 23 of Set 7 | lagunas
# Processing Record 24 of Set 7 | kampene
# Processing Record 25 of Set 7 | kingston
# Processing Record 26 of Set 7 | midvagur
# Processing Record 27 of Set 7 | kzyltu
# Processing Record 28 of Set 7 | nguigmi
# Processing Record 29 of Set 7 | hotan
# Processing Record 30 of Set 7 | crane
# Processing Record 31 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 32 of Set 7 | timbuktu
# Processing Record 33 of Set 7 | basoko
# Processing Record 34 of Set 7 | labrador city
# Processing Record 35 of Set 7 | sandakan
# Processing Record 36 of Set 7 | saint-pol-de-leon
# Processing Record 37 of Set 7 | polyarnyy
# Processing Record 38 of Set 7 | san fernando de monte cristi
# Processing Record 39 of Set 7 | buta
# Processing Record 40 of Set 7 | norfolk
# Processing Record 41 of Set 7 | fort mcmurray
# Processing Record 42 of Set 7 | sena madureira
# Processing Record 43 of Set 7 | pandan
# Processing Record 44 of Set 7 | merizo village
# Processing Record 45 of Set 7 | east london
# Processing Record 46 of Set 7 | thinadhoo
# Processing Record 47 of Set 7 | el granada
# Processing Record 48 of Set 7 | kosong
# Processing Record 49 of Set 7 | nanao
# Processing Record 0 of Set 8 | farap
# Processing Record 1 of Set 8 | arkhara
# Processing Record 2 of Set 8 | barra de santo antonio
# Processing Record 3 of Set 8 | quepos
# Processing Record 4 of Set 8 | nagqu
# Processing Record 5 of Set 8 | den burg
# Processing Record 6 of Set 8 | enkhuizen
# Processing Record 7 of Set 8 | ribeira do pombal
# Processing Record 8 of Set 8 | parksville
# Processing Record 9 of Set 8 | guiuan
# Processing Record 10 of Set 8 | lospalos
# Processing Record 11 of Set 8 | ilomantsi
# Processing Record 12 of Set 8 | senekal
# Processing Record 13 of Set 8 | alice springs
# Processing Record 14 of Set 8 | mirandopolis
# Processing Record 15 of Set 8 | labytnangi
# Processing Record 16 of Set 8 | baker city
# Processing Record 17 of Set 8 | port arthur
# Processing Record 18 of Set 8 | broken hill
# Processing Record 19 of Set 8 | uturoa
# Processing Record 20 of Set 8 | yamethin
# Processing Record 21 of Set 8 | chinde
# Processing Record 22 of Set 8 | ust-nera
# Processing Record 23 of Set 8 | yelabuga
# Processing Record 24 of Set 8 | sur
# Processing Record 25 of Set 8 | dolores
# Processing Record 26 of Set 8 | kronstadt
# Processing Record 27 of Set 8 | acarau
# Processing Record 28 of Set 8 | khovd
# Processing Record 29 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 30 of Set 8 | evanston
# Processing Record 31 of Set 8 | gunjur
# Processing Record 32 of Set 8 | es castell
# Processing Record 33 of Set 8 | mangai
# Processing Record 34 of Set 8 | chita
# Processing Record 35 of Set 8 | conception bay south
# Processing Record 36 of Set 8 | grand forks
# Processing Record 37 of Set 8 | padangsidempuan
# Processing Record 38 of Set 8 | kerikeri
# Processing Record 39 of Set 8 | port lincoln
# Processing Record 40 of Set 8 | illela
# Processing Record 41 of Set 8 | ilhabela
# Processing Record 42 of Set 8 | pingliang
# Processing Record 43 of Set 8 | ataq
# Processing Record 44 of Set 8 | nosy varika
# Processing Record 45 of Set 8 | kabompo
# Processing Record 46 of Set 8 | iturama
# Processing Record 47 of Set 8 | atafu village
# Processing Record 48 of Set 8 | campos do jordao
# Processing Record 49 of Set 8 | ujae
# Processing Record 0 of Set 9 | al ghayzah
# Processing Record 1 of Set 9 | kalmunai
# Processing Record 2 of Set 9 | ballina
# Processing Record 3 of Set 9 | coron
# Processing Record 4 of Set 9 | chissamba
# Processing Record 5 of Set 9 | kosmach
# Processing Record 6 of Set 9 | asamankese
# Processing Record 7 of Set 9 | sitka
# Processing Record 8 of Set 9 | aykhal
# Processing Record 9 of Set 9 | windhoek
# Processing Record 10 of Set 9 | bamboo flat
# Processing Record 11 of Set 9 | kharp
# Processing Record 12 of Set 9 | gobabis
# Processing Record 13 of Set 9 | palmer
# Processing Record 14 of Set 9 | hadibu
# Processing Record 15 of Set 9 | pisco
# Processing Record 16 of Set 9 | kachkanar
# Processing Record 17 of Set 9 | mbengwi
# Processing Record 18 of Set 9 | port isabel
# Processing Record 19 of Set 9 | emerald
# Processing Record 20 of Set 9 | nemuro
# Processing Record 21 of Set 9 | gebeit
# Processing Record 22 of Set 9 | manicore
# Processing Record 23 of Set 9 | san luis de la loma
# Processing Record 24 of Set 9 | ventspils
# Processing Record 25 of Set 9 | masterton
# Processing Record 26 of Set 9 | belyy yar
# Processing Record 27 of Set 9 | vadso
# Processing Record 28 of Set 9 | opuwo
# Processing Record 29 of Set 9 | mount gambier
# Processing Record 30 of Set 9 | yaren
# Processing Record 31 of Set 9 | carbonear
# Processing Record 32 of Set 9 | ituiutaba
# Processing Record 33 of Set 9 | gracemere
# Processing Record 34 of Set 9 | kamina
# Processing Record 35 of Set 9 | caleta de carquin
# Processing Record 36 of Set 9 | nova xavantina
# Processing Record 37 of Set 9 | lufkin
# Processing Record 38 of Set 9 | tangalle
# Processing Record 39 of Set 9 | wenatchee
# Processing Record 40 of Set 9 | bay roberts
# Processing Record 41 of Set 9 | morehead city
# Processing Record 42 of Set 9 | weno
# Processing Record 43 of Set 9 | duki
# Processing Record 44 of Set 9 | gorontalo
# Processing Record 45 of Set 9 | kolonia
# Processing Record 46 of Set 9 | prince rupert
# Processing Record 47 of Set 9 | north bend
# Processing Record 48 of Set 9 | cabo san lucas
# Processing Record 49 of Set 9 | shubarkuduk
# Processing Record 0 of Set 10 | coari
# Processing Record 1 of Set 10 | grabouw
# Processing Record 2 of Set 10 | naze
# Processing Record 3 of Set 10 | caala
# Processing Record 4 of Set 10 | faaa
# Processing Record 5 of Set 10 | barcelos
# Processing Record 6 of Set 10 | potsdam
# Processing Record 7 of Set 10 | selfoss
# Processing Record 8 of Set 10 | tsarychanka
# Processing Record 9 of Set 10 | aden
# Processing Record 10 of Set 10 | murzuq
# Processing Record 11 of Set 10 | hardheim
# Processing Record 12 of Set 10 | azemmour
# Processing Record 13 of Set 10 | petropavlovsk-kamchatsky
# Processing Record 14 of Set 10 | shajiang
# Processing Record 15 of Set 10 | seferihisar
# Processing Record 16 of Set 10 | impfondo
# Processing Record 17 of Set 10 | kuusamo
# Processing Record 18 of Set 10 | balkashino
# Processing Record 19 of Set 10 | mont-tremblant
# Processing Record 20 of Set 10 | progreso
# Processing Record 21 of Set 10 | tarko-sale
# Processing Record 22 of Set 10 | villa gesell
# Processing Record 23 of Set 10 | riberalta
# Processing Record 24 of Set 10 | kudahuvadhoo
# Processing Record 25 of Set 10 | geraldton
# Processing Record 26 of Set 10 | chandia
# Processing Record 27 of Set 10 | laizhou
# Processing Record 28 of Set 10 | priozersk
# Processing Record 29 of Set 10 | rouyn-noranda
# Processing Record 30 of Set 10 | raymondville
# Processing Record 31 of Set 10 | jember
# Processing Record 32 of Set 10 | gizo
# Processing Record 33 of Set 10 | greymouth
# Processing Record 34 of Set 10 | tazovsky
# Processing Record 35 of Set 10 | kurmuk
# Processing Record 36 of Set 10 | kucove
# Processing Record 37 of Set 10 | peniche
# Processing Record 38 of Set 10 | nova sintra
# Processing Record 39 of Set 10 | labuan bajo
# Processing Record 40 of Set 10 | livingston
# Processing Record 41 of Set 10 | doba
# Processing Record 42 of Set 10 | aras-asan
# Processing Record 43 of Set 10 | sovetskaya gavan'
# Processing Record 44 of Set 10 | guadalupe
# Processing Record 45 of Set 10 | kyotera
# Processing Record 46 of Set 10 | jenbach
# Processing Record 47 of Set 10 | ishigaki
# Processing Record 48 of Set 10 | soio
# Processing Record 49 of Set 10 | douglas
# Processing Record 0 of Set 11 | haldensleben i
# Processing Record 1 of Set 11 | essaouira
# Processing Record 2 of Set 11 | krasnoturansk
# Processing Record 3 of Set 11 | fauske
# Processing Record 4 of Set 11 | miramichi
# Processing Record 5 of Set 11 | mutare
# Processing Record 6 of Set 11 | cadale
# Processing Record 7 of Set 11 | san salvador de jujuy
# Processing Record 8 of Set 11 | waat
# Processing Record 9 of Set 11 | smithers
# Processing Record 10 of Set 11 | mount pearl
# Processing Record 11 of Set 11 | balabac
# Processing Record 12 of Set 11 | saryaghash
# Processing Record 13 of Set 11 | kyzylorda
# Processing Record 14 of Set 11 | nelson bay
# Processing Record 15 of Set 11 | bubaque
# Processing Record 16 of Set 11 | lae
# Processing Record 17 of Set 11 | bobbili
# Processing Record 18 of Set 11 | nuuk
# Processing Record 19 of Set 11 | gelnica
# Processing Record 20 of Set 11 | alpu
# Processing Record 21 of Set 11 | cerkno
# Processing Record 22 of Set 11 | farafangana
# Processing Record 23 of Set 11 | porbandar
# Processing Record 24 of Set 11 | nkhata bay
# Processing Record 25 of Set 11 | manukan
# Processing Record 26 of Set 11 | beloyarskiy
# Processing Record 27 of Set 11 | fort st. john
# Processing Record 28 of Set 11 | vysokiy
# Processing Record 29 of Set 11 | oosterzele
# Processing Record 30 of Set 11 | the pas
# Processing Record 31 of Set 11 | rio grande
# Processing Record 32 of Set 11 | xunchang
# Processing Record 33 of Set 11 | sao joao da barra
# Processing Record 34 of Set 11 | kone
# Processing Record 35 of Set 11 | villa union
# Processing Record 36 of Set 11 | smederevo
# Processing Record 37 of Set 11 | kaa-khem
# Processing Record 38 of Set 11 | nizhniy odes
# Processing Record 39 of Set 11 | gamay
# Processing Record 40 of Set 11 | san juan nepomuceno
# Processing Record 41 of Set 11 | pitiquito
# Processing Record 42 of Set 11 | aliabad
# Processing Record 43 of Set 11 | mermoz boabab
# Processing Record 44 of Set 11 | lobito
# Processing Record 45 of Set 11 | charles city
# Processing Record 46 of Set 11 | tofol
# Processing Record 47 of Set 11 | freetown
# Processing Record 48 of Set 11 | walvis bay
# Processing Record 49 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 0 of Set 12 | vila velha
# Processing Record 1 of Set 12 | berdigestyakh
# Processing Record 2 of Set 12 | breckenridge
# Processing Record 3 of Set 12 | melioratorov
# Processing Record 4 of Set 12 | brookings
# Processing Record 5 of Set 12 | meadow lake
# Processing Record 6 of Set 12 | kawthoung
# City not found. Skipping...
# Processing Record 7 of Set 12 | kempston
# Processing Record 8 of Set 12 | yumbe
# Processing Record 9 of Set 12 | el dovio
# Processing Record 10 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 11 of Set 12 | ratnagiri
# Processing Record 12 of Set 12 | isna
# Processing Record 13 of Set 12 | kununurra
# Processing Record 14 of Set 12 | stiens
# Processing Record 15 of Set 12 | tenenkou
# Processing Record 16 of Set 12 | guapiles
# Processing Record 17 of Set 12 | vohipaho
# City not found. Skipping...
# Processing Record 18 of Set 12 | anna regina
# Processing Record 19 of Set 12 | guatrache
# Processing Record 20 of Set 12 | savsjo
# City not found. Skipping...
# Processing Record 21 of Set 12 | phan rang-thap cham
# Processing Record 22 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 23 of Set 12 | san bernardo del viento
# Processing Record 24 of Set 12 | suchedniow
# Processing Record 25 of Set 12 | choele choel
# Processing Record 26 of Set 12 | presque isle
# Processing Record 27 of Set 12 | onguday
# Processing Record 28 of Set 12 | hun
# Processing Record 29 of Set 12 | flying fish cove
# Processing Record 30 of Set 12 | tanjung pandan
# Processing Record 31 of Set 12 | palma sola
# Processing Record 32 of Set 12 | puerto deseado
# Processing Record 33 of Set 12 | rohri
# Processing Record 34 of Set 12 | linlithgow
# Processing Record 35 of Set 12 | nogliki
# Processing Record 36 of Set 12 | saint joseph
# Processing Record 37 of Set 12 | paita
# Processing Record 38 of Set 12 | teknaf
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat      Lng  Max Temp  Humidity  \
# 0            troitsko-pechorsk  62.7084  56.1964     16.98        62
# 1                       gurupi -11.7292 -49.0686     34.29        20
# 2                  thunder bay  48.4001 -89.3168     17.99        77
# 3  edinburgh of the seven seas -37.0676 -12.3116     15.33        93
# 4                    grytviken -54.2811 -36.5092     -5.87        77
#
#    Cloudiness  Wind Speed Country        Date
# 0          61        1.80      RU  1689709930
# 1           5        3.47      BR  1689709930
# 2          75        2.57      CA  1689709637
# 3          86        9.81      SH  1689709700
# 4          21        4.50      GS  1689709931

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                  troitsko-pechorsk  62.7084  56.1964     16.98        62
# 1                             gurupi -11.7292 -49.0686     34.29        20
# 2                        thunder bay  48.4001 -89.3168     17.99        77
# 3        edinburgh of the seven seas -37.0676 -12.3116     15.33        93
# 4                          grytviken -54.2811 -36.5092     -5.87        77
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                61        1.80      RU  1689709930
# 1                 5        3.47      BR  1689709930
# 2                75        2.57      CA  1689709637
# 3                86        9.81      SH  1689709700
# 4                21        4.50      GS  1689709931

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black", alpha=0.8)
today = date.today()
# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature ({today})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black", alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({today})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black", alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x, y, x_label, y_label):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)

    # Regression line
    regression_line = slope * x + intercept

    # Create scatter plot
    plt.scatter(x, y)

    # Plot regression line
    plt.plot(x, regression_line, color="red")

    # Title and labels
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    print(f"r-value is {r_value}")
    # Show the regression equation and correlation coefficient on the plot
    plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}", (min(x), max(y) * 0.9), fontsize=12, color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        troitsko-pechorsk  62.7084  56.1964     16.98        62          61
# 2              thunder bay  48.4001 -89.3168     17.99        77          75
# 5                iskateley  67.6803  53.1512     16.38        91          83
# 7                 sinabang   2.4803  96.3801     25.87        84         100
# 8             longyearbyen  78.2186  15.6401      9.91        62          75
#
#          Wind Speed Country        Date
# City_ID
# 0              1.80      RU  1689709930
# 2              2.57      CA  1689709637
# 5              2.32      RU  1689709931
# 7              2.18      ID  1689709932
# 8              4.12      SJ  1689709932

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 1                             gurupi -11.7292 -49.0686     34.29        20
# 3        edinburgh of the seven seas -37.0676 -12.3116     15.33        93
# 4                          grytviken -54.2811 -36.5092     -5.87        77
# 6                  port-aux-francais -49.3500  70.2167      3.64        88
# 9                     puerto natales -51.7236 -72.4875      0.13        84
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 5        3.47      BR  1689709930
# 3                86        9.81      SH  1689709700
# 4                21        4.50      GS  1689709931
# 6               100       15.25      TF  1689709931
# 9                98        0.57      CL  1689709933

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Latitude", "Max Temperature (°C)")
plt.show()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# r-value is -0.6309034697134506

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Latitude", "Max Temperature (°C)")
plt.show()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# r-value is 0.8196694009507922

# %% [markdown]
# **Discussion about the linear relationship:** Created a good relationship with most cities can be seen on or close to the regression line

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Latitude", "Humidity")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# r-value is 0.02029945372629626

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Latitude", "Humidity")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# r-value is -0.14647511188609663

# %% [markdown]
# **Discussion about the linear relationship:** Relationship between Humidity and Latitude is very weak. Plot shows a regression line around 70% but visually we can see most cities are not anywhere close to that line.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# r-value is -0.07182994186255923

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# r-value is -0.1518231045629369

# %% [markdown]
# **Discussion about the linear relationship:** Weak relationship

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# r-value is -0.07513370289636279

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed")
# Out:
# r-value is -0.1907891497237129Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# **Discussion about the linear relationship:** Created a weak relationship
